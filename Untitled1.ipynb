# %% [markdown]
# <a href="https://colab.research.google.com/github/mvs110/GIS-FALL/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install geopandas==1.0.1
# !pip install mapclassify

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

from google.colab import data_table
data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5a3b87b243bc> in <cell line: 8>()
#       6 #tho not as fancy-interactive as folium or leafmap https://geopandas.org/
#       7
# ----> 8 import mapclassify #need for thematic map classification
#       9
#      10 #will display all output not just last command
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#!python --version
gpd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# # PS0

# %% [markdown]
# # New Section

# %% [markdown]
# I wish to see the non profits interested in population health in Camden county.

# %%
# !wget https://github.com/mvs110/GIS-FALL/raw/main/Municipalities.zip
# Out:
#   File "<ipython-input-2-eb512220c591>", line 1
#     https://github.com/mvs110/GIS-FALL/raw/main/Municipalities.zip
#           ^
# SyntaxError: invalid syntax

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O muni.zip https://github.com/mvs110/GIS-FALL/raw/main/Municipalities.zip

zip_ref = zipfile.ZipFile('muni.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
#njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-207439495e6d> in <cell line: 4>()
#       2 get_ipython().system(' wget -q -O muni.zip https://github.com/mvs110/GIS-FALL/raw/main/Municipalities.zip')
#       3
# ----> 4 zip_ref = zipfile.ZipFile('muni.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
#       5 #njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC
#
# NameError: name 'zipfile' is not defined

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O nj-counties.zip https://docs.google.com/uc?id=1xJDhcRCkgv7k4tNCa72Oog5bohV6dTB2&export=download

zip_ref = zipfile.ZipFile('nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O nj-counties.zip https://docs.google.com/uc?id=1xJDhcRCkgv7k4tNCa72Oog5bohV6dTB2&export=download

zip_ref = zipfile.ZipFile('nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC

# %%
#make the map
njC0.plot()
# Out:
# <Axes: >

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O nj-counties.zip https://docs.google.com/uc?id=1xJDhcRCkgv7k4tNCa72Oog5bohV6dTB2&export=download

zip_ref = zipfile.ZipFile('nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC

# %% [markdown]
# I wish to first observe the municipalities within Camden County, New Jersey. Also to determine the Non-Profits Organization interested in population health in Camden county.

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O nj-muni.zip https://github.com/mvs110/GIS-FALL/raw/main/Municipalities.zip
zip_ref = zipfile.ZipFile('nj-muni.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
m=gpd.read_file('Municipalities.shp') #load the shapefile with gpd as njC

# %%
#make the map
m.plot()
# Out:
# <Axes: >
